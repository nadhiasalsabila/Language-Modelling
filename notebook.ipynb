# %% [markdown]
#  # <center> Penerapan Language Model pada Dataset terkait Tingkat Kekerasan yang Terjadi pada Perempuan dan Anak-anak Selama Pandemi Covid-19 </center>

# %% [markdown]
# **Nama  : Nadhia Salsabila Azzahra**
# <br>
# **NIM   : 1301174653**
# <br>
# **Kelas : NLP-GAB-02**

# %% [markdown]
# ## Read Data

# %% [markdown]
# Data masukan berupa 20 text file berbeda yang terdiri dari judul dan isi yang dipisahkan oleh tag <kalimat><\kalimat>. Pembacaan file menggunakan bantuan library BeautifulSoup yang digunakan untuk memisahkan data antara judul dan isi dengan menggunakan *keyword* **"Kalimat"**. Pada *assignment* ini yang data yang diperlukan hanya isi artikelnya saja.

# %%
from bs4 import BeautifulSoup as BS
import numpy as np
import re
import nltk
import os
import pandas as pd

# %%
#membaca seluruh file yang ada pada folder dataset
folderpath = r"C:\Python38\Scripts\nlp\dataset2"
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data=[]
for path in filepaths :
    file1 = open(path,"r").read()
    soup = BS(file1)
    for item in soup.find_all("kalimat"):
        data.append(item.text[1:-1])

# %%
#mengambil data hanya isi artikelnya saja tanpa judul
isi=''
for artikel in (data[1:][::2]) :
    isi += artikel

# %%
isi
# Out:
# ''

# %%
# file2 = open('summarylagi.txt', 'w')
# file2.write(str(isi))
# file2.close()

# %% [markdown]
# ## PREPROCESSING

# %% [markdown]
# Berikut merupakan tahap-tahap yang dilakukan pada proses preprocessing.
# * **Lower Text** : Merubah seluruh kalimat yang ada menjadi lowercase dengan tujuan agar tidak terjadi ambiguitas kata (cth : Saya dan saya).
# * **Remove New Line** : Menghilangan baris baru atau '\n' agar memudahkan proses pembangunan model bahasa (cth: 'saya\n suka' -> 'saya suka').
# * **Remove Excessive Whitespace** : Menghilangan spasi yang berlebihan (cth: 'saya suka', 'saya suka').
# * **Tokenisasi** : Memecah kalimat menjadi token-token.

# %%
def lowertext(text):
    return text.lower()
isi = lowertext(isi)

# %%
def remove_newline(text):
    return re.sub("\n"," ", text)
isi = remove_newline(isi)

# %%
def remove_excessive_whitespace(text):
    return re.sub('  +', ' ', text)
isi = remove_excessive_whitespace(isi)

# %%
def tokenize_text(isi):
    sent_text = nltk.sent_tokenize(isi)
    # loop per kalimat, tambahkan tag <s> di awal kalimat dan </s> di akhir kalimat
    mod_sentences = [] # array/list untuk menampung semua kalimat teks awal
    for sentence in sent_text:
        mod_sentence = []
        sent_tokens = nltk.word_tokenize(sentence)
        mod_sentence.append('<s>')
        for token in sent_tokens:
          mod_sentence.append(token)
        mod_sentence.append('</s>')
        mod_sentences.append(mod_sentence)
    return mod_sentences

# %%
isi = tokenize_text(isi)

# %% [markdown]
# ## UNIGRAM

# %%
freq_tab = {}
total_count = 0
for sentence in isi:
  for token in sentence:
    if token in freq_tab:
        freq_tab[token] += 1 # kata sudah ada di dictionary, update frekuensinya
    else:
        freq_tab[token] = 1 # kata belum ada di dictionary 
    total_count += 1

# %%
print(total_count)
print(len(freq_tab))
# Out:
# 17042
# 2571

# %%
prob_tab = {}
for token in freq_tab:
    prob_tab[token] = freq_tab[token]/total_count

# %%
test_sentence = "Jika mengalami kekerasan"
lc_test_sentence = test_sentence.lower()
test_tokens = nltk.word_tokenize(lc_test_sentence)
total_prob = 1.0
for test_token in test_tokens:
    total_prob = total_prob * prob_tab[test_token]
    print(test_token)
    
print(total_prob)
# Out:
# jika
# mengalami
# kekerasan
# 3.876388392120931e-08

# %% [markdown]
# ## BIGRAM

# %%
freq_bigram_tab = {}
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_bigram = (sentence[i-1], sentence[i])
    if curr_bigram in freq_bigram_tab:
      freq_bigram_tab[curr_bigram] += 1 # bigram sudah ada di dictionary, update frekuensinya
    else:
      freq_bigram_tab[curr_bigram] = 1 # bigram belum ada di dictionary

# %%
bigram_prob_tab = {}
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_bigram = (sentence[i-1], sentence[i])

    if curr_bigram not in bigram_prob_tab:  
      bigram_prob_tab[curr_bigram] = freq_bigram_tab[curr_bigram]/freq_tab[sentence[i-1]] # bigram belum ada di dictionary, hitung probability

# %% [markdown]
# ## LAPLACE SMOOTHING

# %%
from operator import itemgetter

# %%
def getList(dict): 
    return list(map(itemgetter(0), dict.items())) 

get_freq_tab = getList(freq_tab)

# %%
tab_freq_bigram_ls = {}

# %%
for i in (get_freq_tab):
    for j in (get_freq_tab):
        curr_bgram = (i,j)
        if curr_bgram not in tab_freq_bigram_ls :
            tab_freq_bigram_ls[curr_bgram] = 1
        else :
            continue

# %%
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_bigram = (sentence[i-1], sentence[i])
    if curr_bigram in tab_freq_bigram_ls:
      tab_freq_bigram_ls[curr_bigram] = freq_bigram_tab[curr_bigram]+1

# %%
tab_prob_bigram_ls = {}
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_bigram = (sentence[i-1], sentence[i])

    if curr_bigram not in tab_prob_bigram_ls:
        tab_prob_bigram_ls[curr_bigram] = tab_freq_bigram_ls[curr_bigram]/ (freq_tab.get(sentence[i-1]) + len(freq_tab)) # bigram belum ada di dictionary, hitung probability

# %% [markdown]
# ## PERPLEXITY FOR TEST SET

# %%
text1 = 'kpai menggelar survei kepada anak dan orangtua secara terpisah untuk tau kekerasan kepada anak saat selama pandemi covid-19. Harusnya lebih banyak di rumah jadi saat terbaik untuk berkumpul kembali. namun orangtua tetap bekerja meski di rumah. hal inilah yang menyebabkan kekerasan pada anak'
text2 = "belum ada keputusan resmi soal rencana relaksasi pajak ini, pun berapa usulan insentif yang dikabulkan pemerintah. tapi kalau benar terjadi tentu akan ada koreksi harga jual mobil saat ini. namun sebagai catatan, untuk pajak kendaraan bermotor itu tergantung dari masing-masing daerah. artinya bisa jadi toyota rush di satu daerah bisa lebih murah dibandingkan daerah lainnya."

# %%
print("data uji 1 :"+ text1)
print("data uji 2 :"+ text2)
# Out:
# data uji 1 :kpai menggelar survei kepada anak dan orangtua secara terpisah untuk tau kekerasan kepada anak saat selama pandemi covid-19. Harusnya lebih banyak di rumah jadi saat terbaik untuk berkumpul kembali. namun orangtua tetap bekerja meski di rumah. hal inilah yang menyebabkan kekerasan pada anak
# data uji 2 :belum ada keputusan resmi soal rencana relaksasi pajak ini, pun berapa usulan insentif yang dikabulkan pemerintah. tapi kalau benar terjadi tentu akan ada koreksi harga jual mobil saat ini. namun sebagai catatan, untuk pajak kendaraan bermotor itu tergantung dari masing-masing daerah. artinya bisa jadi toyota rush di satu daerah bisa lebih murah dibandingkan daerah lainnya.

# %%
similar_sent=tokenize_text(text1)

# %%
unsimilar_sent=tokenize_text(text2)

# %%
def count_prob_all(test_sentences) :
    prob_all = 1.0
    for sentence in test_sentences:
        for i in range (1, len(sentence)):
            test_bigram = (sentence[i-1], sentence[i])
            if test_bigram in tab_prob_bigram_ls:
                prob_all=prob_all*tab_prob_bigram_ls.get(test_bigram) # bigram sudah ada di dictionary, update frekuensinya
            else :
                if test_bigram not in freq_tab:
                    freq_tab[sentence[i-1]]=1
                prob_all= prob_all*(freq_tab[sentence[i-1]] / (freq_tab[sentence[i-1]] + len(freq_tab)))
    return prob_all

# %%
def perplexity(sentence,all_prob):
    return pow(1/all_prob, (1/(float(len(sentence)))))

# %%
prob_unsimilar = count_prob_all(unsimilar_sent)

# %%
prob_similar = count_prob_all(similar_sent)

# %%
result_unsim = perplexity(unsimilar_sent, prob_unsimilar)
result_sim=perplexity(similar_sent, prob_similar)

# %%
print("Teks 1 dengan topik Covid-19")
print('Probabilitas :', prob_similar)
print('Perplexity :', result_sim)
print("\nTeks 2 dengan topik Saham Mobil")
print("Probabilitas :", prob_unsimilar)
print('Perplexity :', result_unsim)
# Out:
# Teks 1 dengan topik Covid-19
# Probabilitas : 1.81840570606327e-126
# Perplexity : 2.7231859870553806e+31
#
# Teks 2 dengan topik Saham Mobil
# Probabilitas : 2.3007004679679745e-200
# Perplexity : 8.119606448205397e+49

# %%
d = {'Text': [text1, text2], 'Topik':['Kekerasan selama Covid-19','Harga saham mobil'], 'Nilai Probabilitas': [prob_similar, prob_unsimilar], 'Nilai Perplexity': [result_sim, result_unsim]}
df = pd.DataFrame(data=d)
print("berikut merupakan tabel probabilitas dan perplexity pada data latih")
df
# Out:
#                                                 Text  \
# 0  kpai menggelar survei kepada anak dan orangtua...
# 1  belum ada keputusan resmi soal rencana relaksa...
#
#                        Topik  Nilai Probabilitas  Nilai Perplexity
# 0  Kekerasan selama Covid-19       1.818406e-126      2.723186e+31
# 1          Harga saham mobil       2.300700e-200      8.119606e+49

# %% [markdown]
# ## TRIGRAM

# %%
#proses menghitung frekuensi trigram berdasarkan data latih
freq_trigram_tab = {}
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_trigram = (sentence[i-2], sentence[i-1], sentence[i])
    if curr_trigram in freq_trigram_tab:
      freq_trigram_tab[curr_trigram] += 1 # bigram sudah ada di dictionary, update frekuensinya
    else:
      freq_trigram_tab[curr_trigram] = 1 # bigram belum ada di dictionary

# %%
#proses menghitung probabilitas trigram berdasarkan data latih
trigram_prob_tab = {}
for sentence in isi:
  for i in range (1, len(sentence)):
    curr_trigram = (sentence[i-2],sentence[i-1], sentence[i])

    if curr_trigram not in trigram_prob_tab:  
      trigram_prob_tab[curr_trigram] = freq_trigram_tab[curr_trigram]/(freq_tab[sentence[i-2]]+freq_tab[sentence[i-1]]) # trigram belum ada di dictionary, hitung probability

# %%
#menampilkan probabilitas trigram
# print(trigram_prob_tab)
# Out:
# {('</s>', '<s>', 'kpai'): 0.0014727540500736377,
#  ('<s>', 'kpai', 'menggelar'): 0.0014326647564469914,
#  ('kpai', 'menggelar', 'survei'): 0.05,
#  ('menggelar', 'survei', 'kepada'): 0.07692307692307693,
#  ('survei', 'kepada', 'anak'): 0.05405405405405406,
#  ('kepada', 'anak', 'dan'): 0.007978723404255319,
#  ('anak', 'dan', 'orangtua'): 0.004267425320056899,
#  ('dan', 'orangtua', 'secara'): 0.0025575447570332483,
#  ('orangtua', 'secara', 'terpisah'): 0.012345679012345678,
#  ('secara', 'terpisah', 'untuk'): 0.021739130434782608,
#  ('terpisah', 'untuk', 'mengetahui'): 0.008403361344537815,
#  ('untuk', 'mengetahui', 'kekerasan'): 0.008403361344537815,
#  ('mengetahui', 'kekerasan', 'kepada'): 0.0033222591362126247,
#  ('kekerasan', 'kepada', 'anak-anak'): 0.003105590062111801,
#  ('kepada', 'anak-anak', 'saat'): 0.014492753623188406,
#  ('anak-anak', 'saat', 'selama'): 0.010309278350515464,
#  ('saat', 'selama', 'pandemi'): 0.007462686567164179,
#  ('selama', 'pandemi', 'covid-19'): 0.09223300970873786,
#  ('pandemi', 'covid-19', '.'): 0.08849557522123894,
#  ('covid-19', '.', '</s>'): 0.03870967741935484,
#  ('</s>', '<s>', 'hal'): 0.008836524300441826,
#  ('<s>', 'hal', 'itu'): 0.005681818181818182,
#  ('hal', 'itu', 'diketahui'): 0.00819672131147541,
#  ('itu', 'diketahui', 'setelah'): 0.010101010101010102,
#  ('diketahui', 'setelah', 'kpai'): 0.07692307692307693,
#  ('setelah', 'kpai', 'melakukan'): 0.03333333333333333,
#  ('kpai', 'melakukan', 'survei'): 0.01818181818181818,
#  ('melakukan', 'survei', 'secara'): 0.020833333333333332,
#  ('survei', 'secara', 'terpisah'): 0.018518518518518517,
#  ('secara', 'terpisah', 'kepada'): 0.021739130434782608,
#  ('terpisah', 'kepada', 'anak'): 0.034482758620689655,
#  ('dan', 'orangtua', '.'): 0.005115089514066497,
#  ('orangtua', '.', '</s>'): 0.004207573632538569,
#  ('</s>', '<s>', 'survei'): 0.0014727540500736377,
#  ('<s>', 'survei', 'ini'): 0.001447178002894356,
#  ('survei', 'ini', 'memiliki'): 0.007518796992481203,
#  ('ini', 'memiliki', 'responden'): 0.007042253521126761,
#  ('memiliki', 'responden', 'orangtua'): 0.043478260869565216,
#  ('responden', 'orangtua', 'perempuan'): 0.024390243902439025,
#  ('orangtua', 'perempuan', 'lebih'): 0.004651162790697674,
#  ('perempuan', 'lebih', 'besar'): 0.0045045045045045045,
#  ('lebih', 'besar', 'yaitu'): 0.01639344262295082,
#  ('besar', 'yaitu', '74,4'): 0.047619047619047616,
#  ('yaitu', '74,4', 'persen'): 0.14285714285714285,
#  ('74,4', 'persen', 'dan'): 0.03125,
#  ('persen', 'dan', 'laki-laki'): 0.0026109660574412533,
#  ('dan', 'laki-laki', '25,6'): 0.00267379679144385,
#  ('laki-laki', '25,6', 'persen'): 0.043478260869565216,
#  ('25,6', 'persen', '.'): 0.03125,
#  ('persen', '.', '</s>'): 0.005673758865248227,
#  ('</s>', '<s>', 'dalam'): 0.005154639175257732,
#  ('<s>', 'dalam', 'survei'): 0.0012610340479192938,
#  ('dalam', 'survei', 'secara'): 0.007936507936507936,
#  ('survei', 'secara', 'online'): 0.018518518518518517,
#  ('secara', 'online', 'mulai'): 0.0136986301369863,
#  ('online', 'mulai', '8-14'): 0.02631578947368421,
#  ('mulai', '8-14', 'juni'): 0.125,
#  ('8-14', 'juni', '2020'): 0.16666666666666666,
#  ('juni', '2020', 'melibatkan'): 0.03333333333333333,
#  ('2020', 'melibatkan', '25.146'): 0.037037037037037035,
#  ('melibatkan', '25.146', 'anak'): 0.3333333333333333,
#  ('25.146', 'anak', 'dan'): 0.002840909090909091,
#  ('anak', 'dan', '14.169'): 0.001422475106685633,
#  ('dan', '14.169', 'orangtua'): 0.0028328611898017,
#  ('14.169', 'orangtua', 'tersebar'): 0.025,
#  ('orangtua', 'tersebar', 'di'): 0.025,
#  ('tersebar', 'di', '34'): 0.003676470588235294,
#  ('di', '34', 'provinsi'): 0.0072992700729927005,
#  ('34', 'provinsi', 'indonesia'): 0.09090909090909091,
#  ('provinsi', 'indonesia', '.'): 0.01818181818181818,
#  ('indonesia', '.', '</s>'): 0.006934812760055479,
#  ('</s>', '<s>', 'berdasarkan'): 0.005891016200294551,
#  ('<s>', 'berdasarkan', 'hasil'): 0.001440922190201729,
#  ('berdasarkan', 'hasil', 'survei'): 0.1111111111111111,
#  ('hasil', 'survei', 'kepada'): 0.06666666666666667,
#  ('kepada', 'anak', ','): 0.005319148936170213,
#  ('anak', ',', 'pengasuhan'): 0.0007396449704142012,
#  (',', 'pengasuhan', 'dominan'): 0.0009746588693957114,
#  ('pengasuhan', 'dominan', 'dilakukan'): 0.03571428571428571,
#  ('dominan', 'dilakukan', 'oleh'): 0.038461538461538464,
#  ('dilakukan', 'oleh', 'ibu'): 0.01639344262295082,
#  ('oleh', 'ibu', '.'): 0.017241379310344827,
#  ('ibu', '.', '</s>'): 0.001440922190201729,
#  ('</s>', '<s>', 'para'): 0.0007363770250368188,
#  ('<s>', 'para', 'ibu'): 0.00145985401459854,
#  ('para', 'ibu', 'mengedukasi'): 0.038461538461538464,
#  ('ibu', 'mengedukasi', 'anak'): 0.047619047619047616,
#  ('mengedukasi', 'anak', 'seperti'): 0.002840909090909091,
#  ('anak', 'seperti', 'memberi'): 0.002583979328165375,
#  ('seperti', 'memberi', 'tahu'): 0.025,
#  ('memberi', 'tahu', 'protokol'): 0.1111111111111111,
#  ('tahu', 'protokol', 'pencegahan'): 0.05555555555555555,
#  ('protokol', 'pencegahan', ','): 0.047619047619047616,
#  ('pencegahan', ',', 'mendampingi'): 0.0009910802775024777,
#  (',', 'mendampingi', 'anak'): 0.0019880715705765406,
#  ('mendampingi', 'anak', 'saat'): 0.0028089887640449437,
#  ('anak', 'saat', 'belajar'): 0.0024752475247524753,
#  ('saat', 'belajar', ','): 0.0125,
#  ('belajar', ',', 'mendampingi'): 0.0009727626459143969,
#  ('mendampingi', 'anak', 'beraktivitas'): 0.0028089887640449437,
#  ('anak', 'beraktivitas', 'selama'): 0.0028328611898017,
#  ('beraktivitas', 'selama', 'pandemi'): 0.012048192771084338,
#  ('pandemi', 'covid-19', ','): 0.05752212389380531,
#  ('covid-19', ',', 'mengajak'): 0.0009074410163339383,
#  (',', 'mengajak', 'beribadah'): 0.0009950248756218905,
#  ('mengajak', 'beribadah', ','): 0.14285714285714285,
#  ('beribadah', ',', 'hingga'): 0.00099601593625498,
#  (',', 'hingga', 'mengajak'): 0.0009784735812133072,
#  ('hingga', 'mengajak', 'peduli'): 0.04,
#  ('mengajak', 'peduli', 'pada'): 0.14285714285714285,
#  ('peduli', 'pada', 'sesama'): 0.00684931506849315,
#  ('pada', 'sesama', '.'): 0.006896551724137931,
#  ('sesama', '.', '</s>'): 0.0014792899408284023,
#  ('</s>', '<s>', '``'): 0.05743740795287187,
#  ('<s>', '``', 'sementara'): 0.0025806451612903226,
#  ('``', 'sementara', ','): 0.008403361344537815,
#  ('sementara', ',', '21'): 0.0009765625,
#  (',', '21', 'persen'): 0.0009970089730807576,
#  ('21', 'persen', 'ayah'): 0.030303030303030304,
#  ('persen', 'ayah', 'tidak'): 0.023255813953488372,
#  ('ayah', 'tidak', 'pernah'): 0.007874015748031496,
#  ('tidak', 'pernah', 'mendampingi'): 0.008064516129032258,
#  ('pernah', 'mendampingi', 'anak'): 0.07142857142857142,
#  ('mendampingi', 'anak', 'belajar'): 0.0028089887640449437,
#  ('anak', 'belajar', 'dan'): 0.0026455026455026454,
#  ('belajar', 'dan', 'sebanyak'): 0.002638522427440633,
#  ('dan', 'sebanyak', '17,5'): 0.0027100271002710027,
#  ('sebanyak', '17,5', 'persen'): 0.05555555555555555,
#  ('17,5', 'persen', 'tidak'): 0.03125,
#  ('persen', 'tidak', 'pernah'): 0.00684931506849315,
#  ('tidak', 'pernah', 'menemani'): 0.008064516129032258,
#  ('pernah', 'menemani', 'anak'): 0.1,
#  ('menemani', 'anak', 'beraktivitas'): 0.002840909090909091,
#  ('anak', 'beraktivitas', ','): 0.0028328611898017,
#  ('beraktivitas', ',', "''"): 0.0009970089730807576,
#  (',', "''", 'kata'): 0.014611872146118721,
#  ("''", 'kata', 'ketua'): 0.008403361344537815,
#  ('kata', 'ketua', 'kpai'): 0.030303030303030304,
#  ('ketua', 'kpai', ','): 0.037037037037037035,
#  ('kpai', ',', 'susanto'): 0.000980392156862745,
#  (',', 'susanto', 'melalui'): 0.0009940357852882703,
#  ('susanto', 'melalui', 'keterangan'): 0.05555555555555555,
#  ('melalui', 'keterangan', 'tertulisnya'): 0.045454545454545456,
#  ('keterangan', 'tertulisnya', ','): 0.1,
#  ('tertulisnya', ',', 'kamis'): 0.000998003992015968,
#  (',', 'kamis', '('): 0.00298804780876494,
#  ('kamis', '(', '23/7/2020'): 0.008771929824561403,
#  ('(', '23/7/2020', ')'): 0.008928571428571428,
#  ('23/7/2020', ')', '.'): 0.008928571428571428,
#  (')', '.', '</s>'): 0.035668789808917196,
#  ('</s>', '<s>', 'namun'): 0.013991163475699559,
#  ('<s>', 'namun', 'saat'): 0.0014184397163120568,
#  ('namun', 'saat', 'mendapatkan'): 0.012658227848101266,
#  ('saat', 'mendapatkan', 'pengasuhan'): 0.016666666666666666,
#  ('mendapatkan', 'pengasuhan', ','): 0.03125,
#  ('pengasuhan', ',', 'anak'): 0.0009746588693957114,
#  (',', 'anak', 'mengaku'): 0.0007396449704142012,
#  ('anak', 'mengaku', 'kerap'): 0.002785515320334262,
#  ('mengaku', 'kerap', 'kali'): 0.1,
#  ('kerap', 'kali', 'mengalami'): 0.058823529411764705,
#  ('kali', 'mengalami', 'kekerasan'): 0.02040816326530612,
#  ('mengalami', 'kekerasan', 'fisik'): 0.00906344410876133,
#  ('kekerasan', 'fisik', 'dari'): 0.0060790273556231,
#  ('fisik', 'dari', 'kedua'): 0.005988023952095809,
#  ('dari', 'kedua', 'orang'): 0.0070921985815602835,
#  ('kedua', 'orang', 'tuanya'): 0.02040816326530612,
#  ('orang', 'tuanya', '.'): 0.04,
#  ('tuanya', '.', '</s>'): 0.005865102639296188,
#  ('</s>', '<s>', 'seperti'): 0.0029455081001472753,
#  ('<s>', 'seperti', 'dicubit'): 0.0013986013986013986,
#  ('seperti', 'dicubit', '('): 0.02702702702702703,
#  ('dicubit', '(', '39,8'): 0.008928571428571428,
#  ('(', '39,8', '%'): 0.008928571428571428,
#  ('39,8', '%', ')'): 0.02631578947368421,
#  ('%', ')', ','): 0.06756756756756757,
#  (')', ',', 'dijewer'): 0.0008992805755395684,
#  (',', 'dijewer', '('): 0.000998003992015968,
#  ('dijewer', '(', '19,5'): 0.008928571428571428,
#  ('(', '19,5', '%'): 0.008928571428571428,
#  ('19,5', '%', ')'): 0.02631578947368421,
#  (')', ',', 'dipukul'): 0.0008992805755395684,
#  (',', 'dipukul', '('): 0.000998003992015968,
#  ('dipukul', '(', '10,6'): 0.008928571428571428,
#  ('(', '10,6', '%'): 0.008928571428571428,
#  ('10,6', '%', ')'): 0.02631578947368421,
#  (')', ',', 'ditarik'): 0.0008992805755395684,
#  (',', 'ditarik', '('): 0.000998003992015968,
#  ('ditarik', '(', '7,7'): 0.008928571428571428,
#  ('(', '7,7', '%'): 0.008928571428571428,
#  ('7,7', '%', ')'): 0.02631578947368421,
#  ('%', ')', '.'): 0.02702702702702703,
#  ('</s>', '<s>', 'anak'): 0.0014727540500736377,
#  ('<s>', 'anak', 'menyebut'): 0.000970873786407767,
#  ('anak', 'menyebut', 'pelaku'): 0.0028089887640449437,
#  ('menyebut', 'pelaku', 'kekerasan'): 0.02857142857142857,
#  ('pelaku', 'kekerasan', 'fisik'): 0.0030581039755351682,
#  ('kekerasan', 'fisik', 'yaitu'): 0.00303951367781155,
#  ('fisik', 'yaitu', 'ibu'): 0.02631578947368421,
#  ('yaitu', 'ibu', 'sebanyak'): 0.038461538461538464,
#  ('ibu', 'sebanyak', '60,4'): 0.02702702702702703,
#  ('sebanyak', '60,4', 'persen'): 0.05555555555555555,
#  ('60,4', 'persen', ','): 0.03125,
#  ('persen', ',', 'kakak'): 0.0009689922480620155,
#  (',', 'kakak', 'atau'): 0.0009970089730807576,
#  ('kakak', 'atau', 'adik'): 0.030303030303030304,
#  ('atau', 'adik', '36,5'): 0.014285714285714285,
#  ('adik', '36,5', 'persen'): 0.14285714285714285,
#  ('36,5', 'persen', ','): 0.03125,
#  ('persen', ',', 'dan'): 0.001937984496124031,
#  (',', 'dan', 'ayah'): 0.0007390983000739098,
#  ('dan', 'ayah', '27,4'): 0.0027472527472527475,
#  ('ayah', '27,4', 'persen'): 0.07692307692307693,
#  ('27,4', 'persen', '.'): 0.03125,
#  ('</s>', '<s>', 'sementara'): 0.008836524300441826,
#  ('<s>', 'sementara', 'dari'): 0.0014245014245014246,
#  ('sementara', 'dari', 'sisi'): 0.006329113924050633,
#  ('dari', 'sisi', 'orang'): 0.014084507042253521,
#  ('sisi', 'orang', 'tua'): 0.020202020202020204,
#  ('orang', 'tua', ','): 0.01910828025477707,
#  ('tua', ',', 'sebanyak'): 0.001876172607879925,
#  (',', 'sebanyak', '32,3'): 0.0009823182711198428,
#  ('sebanyak', '32,3', 'persen'): 0.05555555555555555,
#  ('32,3', 'persen', 'ayah'): 0.03125,
#  ('persen', 'ayah', 'dan'): 0.046511627906976744,
#  ('ayah', 'dan', '42,5'): 0.0027472527472527475,
#  ('dan', '42,5', 'persen'): 0.0028328611898017,
#  ('42,5', 'persen', 'ibu'): 0.03125,
#  ('persen', 'ibu', 'mengakui'): 0.0196078431372549,
#  ('ibu', 'mengakui', 'melakukan'): 0.045454545454545456,
#  ('mengakui', 'melakukan', 'kekerasan'): 0.02631578947368421,
#  ('melakukan', 'kekerasan', 'fisik'): 0.003003003003003003,
#  ('kekerasan', 'fisik', '.'): 0.0060790273556231,
#  ('fisik', '.', '</s>'): 0.00424929178470255,
#  ('</s>', '<s>', 'selain'): 0.011045655375552283,
#  ('<s>', 'selain', 'fisik'): 0.0014285714285714286,
#  ('selain', 'fisik', ','): 0.018867924528301886,
#  ('fisik', ',', 'kekerasan'): 0.000968054211035818,
#  (',', 'kekerasan', 'psikis'): 0.0007704160246533128,
#  ('kekerasan', 'psikis', 'juga'): 0.0032258064516129032,
#  ('psikis', 'juga', 'sering'): 0.01,
#  ('juga', 'sering', 'diterima'): 0.01098901098901099,
#  ('sering', 'diterima', 'oleh'): 0.125,
#  ('diterima', 'oleh', 'anak'): 0.023809523809523808,
#  ('oleh', 'anak', '.'): 0.002570694087403599,
#  ('anak', '.', '</s>'): 0.04,
#  ('<s>', 'seperti', 'dimarahi'): 0.0013986013986013986,
#  ('seperti', 'dimarahi', '('): 0.02702702702702703,
#  ('dimarahi', '(', '56'): 0.008928571428571428,
#  ('(', '56', '%'): 0.008928571428571428,
#  ('56', '%', ')'): 0.02631578947368421,
#  (')', ',', 'dibandingkan'): 0.0008992805755395684,
#  (',', 'dibandingkan', 'dengan'): 0.0049504950495049506,
#  ('dibandingkan', 'dengan', 'anak'): 0.007936507936507936,
#  ('dengan', 'anak', 'yang'): 0.002136752136752137,
#  ('anak', 'yang', 'lain'): 0.0013698630136986301,
#  ('yang', 'lain', '('): 0.0024937655860349127,
#  ('lain', '(', '34'): 0.007518796992481203,
#  ('(', '34', '%'): 0.008771929824561403,
#  ('34', '%', ')'): 0.025,
#  (')', ',', 'dibentak'): 0.0008992805755395684,
#  (',', 'dibentak', '('): 0.0009970089730807576,
#  ('dibentak', '(', '23'): 0.008849557522123894,
#  ('(', '23', '%'): 0.008849557522123894,
#  ('23', '%', ')'): 0.02564102564102564,
#  (')', ',', 'dan'): 0.0017985611510791368,
#  (',', 'dan', 'dipelototin'): 0.0007390983000739098,
#  ('dan', 'dipelototin', '('): 0.0028328611898017,
#  ('dipelototin', '(', '13'): 0.008928571428571428,
#  ('(', '13', '%'): 0.008849557522123894,
#  ('13', '%', ')'): 0.02564102564102564,
#  ('<s>', 'berdasarkan', 'pengakuan'): 0.001440922190201729,
#  ('berdasarkan', 'pengakuan', 'sang'): 0.058823529411764705,
#  ('pengakuan', 'sang', 'anak'): 0.14285714285714285,
#  ('sang', 'anak', ','): 0.0028089887640449437,
#  ('anak', ',', 'sebanyak'): 0.0007396449704142012,
#  (',', 'sebanyak', '79'): 0.0009823182711198428,
#  ('sebanyak', '79', 'persen'): 0.05555555555555555,
#  ('79', 'persen', 'ibu'): 0.03125,
#  ('persen', 'ibu', 'melakukan'): 0.0196078431372549,
#  ('ibu', 'melakukan', 'kekerasan'): 0.017857142857142856,
#  ('melakukan', 'kekerasan', 'psikis'): 0.006006006006006006,
#  ('kekerasan', 'psikis', ','): 0.00967741935483871,
#  ('psikis', ',', 'ayak'): 0.0009861932938856016,
#  (',', 'ayak', '42'): 0.000998003992015968,
#  ('ayak', '42', 'persen'): 0.5,
#  ('42', 'persen', ','): 0.03125,
#  (',', 'dan', 'kakak'): 0.0007390983000739098,
#  ('dan', 'kakak', 'atau'): 0.002824858757062147,
#  ('atau', 'adik', '20,4'): 0.014285714285714285,
#  ('adik', '20,4', 'persen'): 0.14285714285714285,
#  ('20,4', 'persen', '.'): 0.03125,
#  ('<s>', '``', 'dari'): 0.0012903225806451613,
#  ('``', 'dari', 'sisi'): 0.004329004329004329,
#  (',', 'sebanyak', '69,6'): 0.0009823182711198428,
#  ('sebanyak', '69,6', 'persen'): 0.05555555555555555,
#  ('69,6', 'persen', 'ayah'): 0.03125,
#  ('ayah', 'dan', 'sebanyak'): 0.0027472527472527475,
#  ('dan', 'sebanyak', '73'): 0.0027100271002710027,
#  ('sebanyak', '73', 'persen'): 0.05555555555555555,
#  ('73', 'persen', 'ibu'): 0.03125,
#  ('persen', 'ibu', 'menyatakan'): 0.0196078431372549,
#  ('ibu', 'menyatakan', 'melakukan'): 0.038461538461538464,
#  ('menyatakan', 'melakukan', 'kekerasan'): 0.023809523809523808,
#  ('psikis', ',', "''"): 0.0009861932938856016,
#  (',', "''", 'katanya'): 0.006392694063926941,
#  ("''", 'katanya', '.'): 0.05555555555555555,
#  ('katanya', '.', '</s>'): 0.01308139534883721,
#  ('</s>', '<s>', 'kendati'): 0.0007363770250368188,
#  ('<s>', 'kendati', 'demikian'): 0.0014705882352941176,
#  ('kendati', 'demikian', ','): 0.14285714285714285,
#  ('demikian', ',', 'anak'): 0.0009930486593843098,
#  (',', 'anak', 'masih'): 0.0007396449704142012,
#  ('anak', 'masih', 'memiliki'): 0.002652519893899204,
#  ('masih', 'memiliki', 'emosi'): 0.02127659574468085,
#  ('memiliki', 'emosi', 'positif'): 0.03225806451612903,
#  ('emosi', 'positif', 'meski'): 0.043478260869565216,
#  ('positif', 'meski', 'mengalami'): 0.05263157894736842,
#  ('meski', 'mengalami', 'kekerasan'): 0.025,
#  ('mengalami', 'kekerasan', '.'): 0.00906344410876133,
#  ('kekerasan', '.', '</s>'): 0.013388259526261586,
#  ('<s>', 'hal', 'ini'): 0.007102272727272727,
#  ('hal', 'ini', 'ditandai'): 0.00684931506849315,
#  ('ini', 'ditandai', 'dengan'): 0.00819672131147541,
#  ('ditandai', 'dengan', 'senang'): 0.00847457627118644,
#  ('dengan', 'senang', 'memiliki'): 0.008333333333333333,
#  ('senang', 'memiliki', 'waktu'): 0.041666666666666664,
#  ('memiliki', 'waktu', 'lebih'): 0.02127659574468085,
#  ('waktu', 'lebih', 'banyak'): 0.013888888888888888,
#  ('lebih', 'banyak', 'untuk'): 0.009174311926605505,
#  ('banyak', 'untuk', 'membantu'): 0.0056179775280898875,
#  ('untuk', 'membantu', 'orang'): 0.008403361344537815,
#  ('membantu', 'orang', 'tua'): 0.010416666666666666,
#  ('orang', 'tua', '('): 0.012738853503184714,
#  ('tua', '(', '60,3'): 0.005681818181818182,
#  ('(', '60,3', '%'): 0.008928571428571428,
#  ('60,3', '%', ')'): 0.02631578947368421,
#  (')', ',', 'lebih'): 0.0008992805755395684,
#  (',', 'lebih', 'dekat'): 0.0009551098376313276,
#  ('lebih', 'dekat', 'dengan'): 0.020833333333333332,
#  ('dekat', 'dengan', 'orang'): 0.008403361344537815,
#  ('dengan', 'orang', 'tua'): 0.014354066985645933,
#  ('tua', '(', '59,7'): 0.005681818181818182,
#  ('(', '59,7', '%'): 0.008928571428571428,
#  ('59,7', '%', ')'): 0.02631578947368421,
#  (',', 'dan', 'kesempatan'): 0.0007390983000739098,
#  ('dan', 'kesempatan', 'belajar'): 0.002793296089385475,
#  ('kesempatan', 'belajar', 'dengan'): 0.030303030303030304,
#  ('belajar', 'dengan', 'orang'): 0.006944444444444444,
#  ('orang', 'tua', 'lebih'): 0.006369426751592357,
#  ('tua', 'lebih', 'banyak'): 0.009009009009009009,
#  ('lebih', 'banyak', '('): 0.009174311926605505,
#  ('banyak', '(', '40,5'): 0.005747126436781609,
#  ('(', '40,5', '%'): 0.008928571428571428,
#  ('40,5', '%', ')'): 0.02631578947368421,
#  ('<s>', 'kpai', 'menjelaskan'): 0.0014326647564469914,
#  ('kpai', 'menjelaskan', ','): 0.03571428571428571,
#  ('menjelaskan', ',', 'beratnya'): 0.0009900990099009901,
#  (',', 'beratnya', 'beban'): 0.000998003992015968,
#  ('beratnya', 'beban', 'domestik'): 0.05555555555555555,
#  ('beban', 'domestik', ','): 0.037037037037037035,
#  ('domestik', ',', 'psikologis'): 0.0009891196834817012,
#  (',', 'psikologis', ','): 0.0019782393669634025,
#  ('psikologis', ',', 'dan'): 0.0009891196834817012,
#  (',', 'dan', 'tanggung'): 0.0007390983000739098,
#  ('dan', 'tanggung', 'jawab'): 0.0028328611898017,
#  ('tanggung', 'jawab', 'pengasuhan'): 0.5,
#  ('jawab', 'pengasuhan', 'yang'): 0.038461538461538464,
#  ('pengasuhan', 'yang', 'bertumpu'): 0.0024752475247524753,
#  ('yang', 'bertumpu', 'pada'): 0.002631578947368421,
#  ('bertumpu', 'pada', 'seorang'): 0.006944444444444444,
#  ('pada', 'seorang', 'ibu'): 0.006802721088435374,
#  ('seorang', 'ibu', 'menjadi'): 0.041666666666666664,
#  ('ibu', 'menjadi', 'faktor'): 0.011764705882352941,
#  ('menjadi', 'faktor', 'kekerasan'): 0.013513513513513514,
#  ('faktor', 'kekerasan', 'terhadap'): 0.0032679738562091504,
#  ('kekerasan', 'terhadap', 'anak'): 0.06684491978609626,
#  ('terhadap', 'anak', 'di'): 0.004672897196261682,
#  ('anak', 'di', 'masa'): 0.00482315112540193,
#  ('di', 'masa', 'pandemi'): 0.046296296296296294,
#  ('masa', 'pandemi', 'covid-19'): 0.09550561797752809,
#  ('pandemi', 'covid-19', 'ini'): 0.01327433628318584,
#  ('covid-19', 'ini', '.'): 0.009009009009009009,
#  ('ini', '.', '</s>'): 0.01761006289308176,
#  ('<s>', 'sementara', ','): 0.002849002849002849,
#  ('sementara', ',', 'beban'): 0.0009765625,
#  (',', 'beban', 'ayah'): 0.0009823182711198428,
#  ('beban', 'ayah', 'dalam'): 0.034482758620689655,
#  ('ayah', 'dalam', 'mengasuh'): 0.015873015873015872,
#  ('dalam', 'mengasuh', 'anak'): 0.02564102564102564,
#  ('mengasuh', 'anak', 'sangat'): 0.002824858757062147,
#  ('anak', 'sangat', 'minim'): 0.0027100271002710027,
#  ('sangat', 'minim', '.'): 0.05,
#  ('minim', '.', '</s>'): 0.0014792899408284023,
#  ('<s>', '``', 'kondisi'): 0.0012903225806451613,
#  ('``', 'kondisi', 'ketidakadilan'): 0.0078125,
#  ('kondisi', 'ketidakadilan', 'dalam'): 0.030303030303030304,
#  ('ketidakadilan', 'dalam', 'urusan'): 0.008695652173913044,
#  ('dalam', 'urusan', 'rumah'): 0.008547008547008548,
#  ('urusan', 'rumah', 'tangga'): 0.015037593984962405,
#  ('rumah', 'tangga', 'yang'): 0.025477707006369428,
#  ('tangga', 'yang', 'dialami'): 0.0024630541871921183,
#  ('yang', 'dialami', 'ibu'): 0.002512562814070352,
#  ('dialami', 'ibu', 'dan'): 0.02564102564102564,
#  ('ibu', 'dan', 'kekerasan'): 0.002688172043010753,
#  ('dan', 'kekerasan', 'dalam'): 0.0030816640986132513,
#  ('kekerasan', 'dalam', 'rumah'): 0.0340632603406326,
#  ('dalam', 'rumah', 'tangga'): 0.05737704918032787,
#  ('rumah', 'tangga', 'selama'): 0.012738853503184714,
#  ('tangga', 'selama', 'covid-19'): 0.009259259259259259,
#  ('selama', 'covid-19', 'secara'): 0.005494505494505495,
#  ('covid-19', 'secara', 'terus'): 0.006993006993006993,
#  ('secara', 'terus', 'menerus'): 0.0196078431372549,
#  ('terus', 'menerus', 'berefek'): 0.1,
#  ('menerus', 'berefek', 'domino'): 0.5,
#  ('berefek', 'domino', '['): 0.5,
#  ('domino', '[', 'kekerasan'): 0.16666666666666666,
#  ('[', 'kekerasan', ']'): 0.009933774834437087,
#  ('kekerasan', ']', 'kepada'): 0.0033112582781456954,
#  (']', 'kepada', 'anak'): 0.03333333333333333,
#  ('anak', ',', "''"): 0.005177514792899409,
#  (',', "''", 'ucapnya'): 0.0018264840182648401,
#  ("''", 'ucapnya', '.'): 0.02040816326530612,
#  ('ucapnya', '.', '</s>'): 0.004424778761061947,
#  ('<s>', 'selain', 'itu'): 0.012857142857142857,
#  ('selain', 'itu', ','): 0.1016949152542373,
#  ('itu', ',', 'kondisi'): 0.0009107468123861566,
#  (',', 'kondisi', 'anak'): 0.000968054211035818,
#  ('kondisi', 'anak', 'yang'): 0.005221932114882507,
#  ('anak', 'yang', 'bosan'): 0.0013698630136986301,
#  ('yang', 'bosan', ','): 0.0025906735751295338,
#  ('bosan', ',', 'serta'): 0.000992063492063492,
#  (',', 'serta', 'aktivitas'): 0.000975609756097561,
#  ('serta', 'aktivitas', 'anak'): 0.02702702702702703,
#  ('aktivitas', 'anak', 'yang'): 0.0027472527472527475,
#  ('anak', 'yang', 'dianggap'): 0.0013698630136986301,
#  ('yang', 'dianggap', 'kurang'): 0.0026109660574412533,
#  ('dianggap', 'kurang', 'produktif'): 0.14285714285714285,
#  ('kurang', 'produktif', 'seperti'): 0.25,
#  ('produktif', 'seperti', 'nonton'): 0.02702702702702703,
#  ('seperti', 'nonton', 'televisi'): 0.02702702702702703,
#  ('nonton', 'televisi', '('): 0.5,
#  ('televisi', '(', '61'): 0.008928571428571428,
#  ('(', '61', '%'): 0.008928571428571428,
#  ('61', '%', ')'): 0.02631578947368421,
#  (')', ',', 'tidur'): 0.0008992805755395684,
#  (',', 'tidur', '60'): 0.0009970089730807576,
#  ('tidur', '60', '%'): 0.25,
#  ('60', '%', ','): 0.02564102564102564,
#  ('%', ',', 'dan'): 0.0009633911368015414,
#  (',', 'dan', 'main'): 0.0007390983000739098,
#  ('dan', 'main', 'gim'): 0.0028328611898017,
#  ('main', 'gim', '('): 0.5,
#  ('gim', '(', '49'): 0.008928571428571428,
#  ('(', '49', '%'): 0.008849557522123894,
#  ('49', '%', ')'): 0.02564102564102564,
#  (')', ',', 'berakibat'): 0.0008992805755395684,
#  (',', 'berakibat', 'pada'): 0.000998003992015968,
#  ('berakibat', 'pada', 'kekerasan'): 0.006944444444444444,
#  ('pada', 'kekerasan', '.'): 0.0022727272727272726,
#  ('<s>', '``', 'keterbukaan'): 0.0012903225806451613,
#  ('``', 'keterbukaan', 'perempuan'): 0.01020408163265306,
#  ('keterbukaan', 'perempuan', 'dalam'): 0.0056179775280898875,
#  ('perempuan', 'dalam', 'pengasuhan'): 0.0034482758620689655,
#  ('dalam', 'pengasuhan', 'dibandingkan'): 0.007194244604316547,
#  ('pengasuhan', 'dibandingkan', 'dengan'): 0.029411764705882353,
#  ('dibandingkan', 'dengan', 'kultur'): 0.007936507936507936,
#  ('dengan', 'kultur', 'laki-laki'): 0.008333333333333333,
#  ('kultur', 'laki-laki', 'yang'): 0.04,
#  ('laki-laki', 'yang', 'cenderung'): 0.0024937655860349127,
#  ('yang', 'cenderung', 'tertutup'): 0.0025575447570332483,
#  ('cenderung', 'tertutup', 'dan'): 0.07142857142857142,
#  ('tertutup', 'dan', 'menjaga'): 0.002824858757062147,
#  ('dan', 'menjaga', 'image'): 0.002777777777777778,
#  ('menjaga', 'image', ','): 0.1111111111111111,
#  ('image', ',', 'serta'): 0.000998003992015968,
#  (',', 'serta', 'dominannya'): 0.000975609756097561,
#  ('serta', 'dominannya', 'data'): 0.04,
#  ('dominannya', 'data', 'responden'): 0.03333333333333333,
#  ('data', 'responden', 'perempuan'): 0.03225806451612903,
#  ('responden', 'perempuan', 'berdampak'): 0.0056179775280898875,
#  ('perempuan', 'berdampak', 'pada'): 0.005263157894736842,
#  ('berdampak', 'pada', 'lebih'): 0.006369426751592357,
#  ('pada', 'lebih', 'banyaknya'): 0.005291005291005291,
#  ('lebih', 'banyaknya', 'perempuan'): 0.02,
#  ('banyaknya', 'perempuan', 'menjadi'): 0.005555555555555556,
#  ('perempuan', 'menjadi', 'pelaku'): 0.004149377593360996,
#  ('menjadi', 'pelaku', ','): 0.010526315789473684,
#  ('pelaku', ',', "''"): 0.0019398642095053346,
#  (',', "''", 'jelas'): 0.006392694063926941,
#  ("''", 'jelas', 'dia'): 0.009433962264150943,
#  ('jelas', 'dia', '.'): 0.017543859649122806,
#  ('dia', '.', '</s>'): 0.009735744089012517,
#  ('</s>', '<s>', 'kemudian'): 0.004418262150220913,
#  ('<s>', 'kemudian', 'berdasarkan'): 0.0014245014245014246,
#  ('kemudian', 'berdasarkan', 'survei'): 0.02631578947368421,
#  ('berdasarkan', 'survei', ','): 0.037037037037037035,
#  ('survei', ',', 'menunjukkan'): 0.0009871668311944718,
#  (',', 'menunjukkan', 'bahwa'): 0.0009881422924901185,
#  ('menunjukkan', 'bahwa', 'hanya'): 0.02631578947368421,
#  ('bahwa', 'hanya', '33,8'): 0.021739130434782608,
#  ('hanya', '33,8', 'persen'): 0.05,
#  ('33,8', 'persen', 'orang'): 0.03125,
#  ('persen', 'orang', 'tua'): 0.008130081300813009,
#  ('orang', 'tua', 'yang'): 0.06369426751592357,
#  ('tua', 'yang', 'pernah'): 0.0022522522522522522,
#  ('yang', 'pernah', 'mengikuti'): 0.002577319587628866,
#  ('pernah', 'mengikuti', 'pelatihan'): 0.1,
#  ('mengikuti', 'pelatihan', 'atau'): 0.3333333333333333,
#  ('pelatihan', 'atau', 'memperoleh'): 0.015151515151515152,
#  ('atau', 'memperoleh', 'informasi'): 0.015384615384615385,
#  ('memperoleh', 'informasi', 'tentang'): 0.1111111111111111,
#  ('informasi', 'tentang', 'pengasuhan'): 0.038461538461538464,
#  ('tentang', 'pengasuhan', '.'): 0.023255813953488372,
#  ('pengasuhan', '.', '</s>'): 0.004291845493562232,
#  ('</s>', '<s>', 'data'): 0.0029455081001472753,
#  ('<s>', 'data', 'ini'): 0.0014124293785310734,
#  ('data', 'ini', 'juga'): 0.006666666666666667,
#  ('ini', 'juga', 'menunjukkan'): 0.004807692307692308,
#  ('juga', 'menunjukkan', 'adanya'): 0.01020408163265306,
#  ('menunjukkan', 'adanya', 'potensi'): 0.034482758620689655,
#  ('adanya', 'potensi', 'gap'): 0.041666666666666664,
#  ('potensi', 'gap', 'antara'): 0.14285714285714285,
#  ('gap', 'antara', 'apa'): 0.041666666666666664,
#  ('antara', 'apa', 'yang'): 0.030303030303030304,
#  ('apa', 'yang', 'dilakukan'): 0.002570694087403599,
#  ('yang', 'dilakukan', 'orang'): 0.0024875621890547263,
#  ('dilakukan', 'orang', 'tua'): 0.017391304347826087,
#  ('orang', 'tua', 'dan'): 0.006369426751592357,
#  ('tua', 'dan', 'diterima'): 0.002398081534772182,
#  ('dan', 'diterima', 'anak'): 0.0028089887640449437,
#  ('diterima', 'anak', 'dalam'): 0.0028169014084507044,
#  ('anak', 'dalam', 'pengasuhan'): 0.002150537634408602,
#  ('dalam', 'pengasuhan', '.'): 0.007194244604316547,
#  ('<s>', '``', 'sehingga'): 0.0025806451612903226,
#  ('``', 'sehingga', 'ke'): 0.008928571428571428,
#  ('sehingga', 'ke', 'depan'): 0.020833333333333332,
#  ('ke', 'depan', 'perlu'): 0.027777777777777776,
#  ('depan', 'perlu', 'peningkatan'): 0.06666666666666667,
#  ('perlu', 'peningkatan', 'pemahaman'): 0.025,
#  ('peningkatan', 'pemahaman', 'tentang'): 0.03225806451612903,
#  ('pemahaman', 'tentang', 'pengasuhan'): 0.05,
#  ('tentang', 'pengasuhan', 'bagi'): 0.023255813953488372,
#  ('pengasuhan', 'bagi', 'ayah'): 0.019230769230769232,
#  ('bagi', 'ayah', 'dan'): 0.02564102564102564,
#  ('ayah', 'dan', 'ibu'): 0.005494505494505495,
#  ('dan', 'ibu', 'sekaligus'): 0.002688172043010753,
#  ('ibu', 'sekaligus', ','): 0.045454545454545456,
#  ('sekaligus', ',', "''"): 0.0009970089730807576,
#  (',', "''", 'tuturnya'): 0.0027397260273972603,
#  ("''", 'tuturnya', '.'): 0.030927835051546393,
#  ('tuturnya', '.', '</s>'): 0.004431314623338257,
#  ('</s>', '<s>', 'oleh'): 0.0022091310751104565,
#  ('<s>', 'oleh', 'karena'): 0.002789400278940028,
#  ('oleh', 'karena', 'itu'): 0.021739130434782608,
#  ('karena', 'itu', ','): 0.026490066225165563,
#  ('itu', ',', 'kpai'): 0.0018214936247723133,
#  (',', 'kpai', 'merekomendasikan'): 0.000980392156862745,
#  ('kpai', 'merekomendasikan', 'agar'): 0.05,
#  ('merekomendasikan', 'agar', 'ayah'): 0.07142857142857142,
#  ('agar', 'ayah', 'dan'): 0.04,
#  ('dan', 'ibu', 'harus'): 0.002688172043010753,
#  ('ibu', 'harus', 'bekerjasama'): 0.01694915254237288,
#  ('harus', 'bekerjasama', 'dalam'): 0.025,
#  ('bekerjasama', 'dalam', 'hal'): 0.008695652173913044,
#  ('dalam', 'hal', 'urusan'): 0.007194244604316547,
#  ('hal', 'urusan', 'rumah'): 0.03571428571428571,
#  ('rumah', 'tangga', 'dan'): 0.01910828025477707,
#  ('tangga', 'dan', 'pengasuhan'): 0.002638522427440633,
#  ('dan', 'pengasuhan', '.'): 0.002652519893899204,
#  ('hal', 'ini', 'akan'): 0.00684931506849315,
#  ('ini', 'akan', 'berdampak'): 0.006060606060606061,
#  ('akan', 'berdampak', 'positif'): 0.017241379310344827,
#  ('berdampak', 'positif', 'pada'): 0.037037037037037035,
#  ('positif', 'pada', 'anak'): 0.019230769230769232,
#  ('pada', 'anak', 'dan'): 0.008097165991902834,
#  ('anak', 'dan', 'mengurangi'): 0.001422475106685633,
#  ('dan', 'mengurangi', 'terjadinya'): 0.002824858757062147,
#  ('mengurangi', 'terjadinya', 'kekerasan'): 0.1,
#  ('terjadinya', 'kekerasan', 'fisik'): 0.003278688524590164,
#  ('kekerasan', 'fisik', 'dan'): 0.00911854103343465,
#  ('fisik', 'dan', 'psikis'): 0.005208333333333333,
#  ('dan', 'psikis', '.'): 0.0027397260273972603,
#  ('psikis', '.', '</s>'): 0.005822416302765648,
#  ('</s>', '<s>', 'perlunya'): 0.0007363770250368188,
#  ('<s>', 'perlunya', 'pembagian'): 0.0014684287812041115,
#  ('perlunya', 'pembagian', 'peran'): 0.3333333333333333,
#  ('pembagian', 'peran', 'yang'): 0.1,
#  ('peran', 'yang', 'baik'): 0.002577319587628866,
#  ('yang', 'baik', 'antara'): 0.0024813895781637717,
#  ('baik', 'antara', 'ibu'): 0.02127659574468085,
#  ('antara', 'ibu', 'dan'): 0.023255813953488372,
#  ('ibu', 'dan', 'ayah'): 0.002688172043010753,
#  ('dan', 'ayah', 'dalam'): 0.0027472527472527475,
#  ('mengasuh', 'anak', ','): 0.005649717514124294,
#  ('anak', ',', 'terutama'): 0.0007396449704142012,
#  (',', 'terutama', 'dalam'): 0.0009910802775024777,
#  ('terutama', 'dalam', 'condisi'): 0.00819672131147541,
#  ('dalam', 'condisi', 'covid-19'): 0.008695652173913044,
#  ('condisi', 'covid-19', 'ini'): 0.00980392156862745,
#  ('</s>', '<s>', 'ayah'): 0.0007363770250368188,
#  ('<s>', 'ayah', 'harus'): 0.001447178002894356,
#  ('ayah', 'harus', 'lebih'): 0.0196078431372549,
#  ('harus', 'lebih', 'banyak'): 0.011764705882352941,
#  ('lebih', 'banyak', 'terlibat'): 0.009174311926605505,
#  ('banyak', 'terlibat', 'dalam'): 0.015625,
#  ('terlibat', 'dalam', 'pengasuhan'): 0.008695652173913044,
#  ('dalam', 'pengasuhan', ','): 0.007194244604316547,
#  ('pengasuhan', ',', 'karena'): 0.0009746588693957114,
#  (',', 'karena', 'sejatinya'): 0.0009478672985781991,
#  ('karena', 'sejatinya', 'anak'): 0.017857142857142856,
#  ('sejatinya', 'anak', 'memerlukan'): 0.0028328611898017,
#  ('anak', 'memerlukan', 'kedua'): 0.002793296089385475,
#  ('memerlukan', 'kedua', 'orang'): 0.07692307692307693,
#  ('</s>', '<s>', 'kelekatan'): 0.0007363770250368188,
#  ('<s>', 'kelekatan', 'anak'): 0.0014705882352941176,
#  ('kelekatan', 'anak', 'dengan'): 0.002840909090909091,
#  ('anak', 'dengan', 'orang'): 0.002136752136752137,
#  ('orang', 'tua', 'sangat'): 0.01910828025477707,
#  ('tua', 'sangat', 'diperlukan'): 0.012048192771084338,
#  ('sangat', 'diperlukan', 'untuk'): 0.047619047619047616,
#  ('diperlukan', 'untuk', 'optimalnya'): 0.00847457627118644,
#  ('untuk', 'optimalnya', 'tumbuh'): 0.008620689655172414,
#  ('optimalnya', 'tumbuh', 'kembang'): 0.16666666666666666,
#  ('tumbuh', 'kembang', 'anak'): 0.3,
#  ('kembang', 'anak', '.'): 0.0028089887640449437,
#  ('<s>', '``', 'selain'): 0.0025806451612903226,
#  ('``', 'selain', 'itu'): 0.017094017094017096,
#  ('itu', ',', 'perlunya'): 0.0009107468123861566,
#  (',', 'perlunya', 'promosi'): 0.0009970089730807576,
#  ('perlunya', 'promosi', 'layanan'): 0.3333333333333333,
#  ('promosi', 'layanan', 'konsultasi'): 0.038461538461538464,
#  ('layanan', 'konsultasi', 'dan'): 0.03225806451612903,
#  ('konsultasi', 'dan', 'penanganan'): 0.002793296089385475,
#  ('dan', 'penanganan', 'kasus'): 0.0026666666666666666,
#  ('penanganan', 'kasus', 'kepada'): 0.00641025641025641,
#  ('kasus', 'kepada', 'anak'): 0.006329113924050633,
#  ('anak', 'dan', 'orang'): 0.002844950213371266,
#  ('dan', 'orang', 'tua'): 0.009009009009009009,
#  ('orang', 'tua', 'agar'): 0.006369426751592357,
#  ('tua', 'agar', 'jika'): 0.01282051282051282,
#  ('agar', 'jika', 'mengalami'): 0.03125,
#  ('jika', 'mengalami', 'kekerasan'): 0.018867924528301886,
#  ('mengalami', 'kekerasan', 'dapat'): 0.0030211480362537764,
#  ('kekerasan', 'dapat', 'mengadu'): 0.0030303030303030303,
#  ('dapat', 'mengadu', 'ke'): 0.02564102564102564,
#  ('mengadu', 'ke', 'tempat'): 0.02631578947368421,
#  ('ke', 'tempat', 'yang'): 0.023255813953488372,
#  ('tempat', 'yang', 'tepat'): 0.002564102564102564,
#  ('yang', 'tepat', 'dan'): 0.002617801047120419,
#  ('tepat', 'dan', 'ditangani'): 0.0028169014084507044,
#  ('dan', 'ditangani', 'dengan'): 0.0028328611898017,
#  ('ditangani', 'dengan', 'baik'): 0.00847457627118644,
#  ('dengan', 'baik', ','): 0.0070921985815602835,
#  ('baik', ',', "''"): 0.001951219512195122,
#  (',', "''", 'tuturnya.kasus'): 0.0009132420091324201,
#  ("''", 'tuturnya.kasus', 'kekerasan'): 0.010526315789473684,
#  ('tuturnya.kasus', 'kekerasan', 'juga'): 0.003355704697986577,
#  ('kekerasan', 'juga', 'masih'): 0.005208333333333333,
#  ('juga', 'masih', 'membayangi'): 0.017699115044247787,
#  ('masih', 'membayangi', 'hari-hari'): 0.07142857142857142,
#  ('membayangi', 'hari-hari', 'banyak'): 0.5,
#  ('hari-hari', 'banyak', 'anak'): 0.03076923076923077,
#  ('banyak', 'anak', 'di'): 0.004830917874396135,
#  ('anak', 'di', 'indonesia'): 0.006430868167202572,
#  ('di', 'indonesia', 'semasa'): 0.006289308176100629,
#  ('indonesia', 'semasa', 'pandemi'): 0.04,
#  ('semasa', 'pandemi', '.'): 0.015625,
#  ('pandemi', '.', '</s>'): 0.016270337922403004,
#  ('</s>', '<s>', 'suara.com'): 0.0007363770250368188,
#  ('<s>', 'suara.com', '-'): 0.0014619883040935672,
#  ('suara.com', '-', 'tidak'): 0.06666666666666667,
#  ('-', 'tidak', 'hanya'): 0.008,
#  ('tidak', 'hanya', 'virus'): 0.007462686567164179,
#  ('hanya', 'virus', 'corona'): 0.030303030303030304,
#  ('virus', 'corona', 'atau'): 0.038461538461538464,
#  ('corona', 'atau', 'covid-19'): 0.013157894736842105,
#  ('atau', 'covid-19', 'yang'): 0.006060606060606061,
#  ('covid-19', 'yang', 'mengancam'): 0.0020833333333333333,
#  ('yang', 'mengancam', 'anak'): 0.0026109660574412533,
#  ('mengancam', 'anak', 'di'): 0.0028169014084507044,
#  ('masa', 'pandemi', '.'): 0.02247191011235955,
#  ('</s>', '<s>', 'kasus'): 0.0022091310751104565,
#  ('<s>', 'kasus', 'kekerasan'): 0.0012315270935960591,
#  ('kasus', 'kekerasan', 'juga'): 0.002325581395348837,
#  ('</s>', '<s>', 'kementerian'): 0.0029455081001472753,
#  ('<s>', 'kementerian', 'pemberdayaan'): 0.005689900426742532,
#  ('kementerian', 'pemberdayaan', 'perempuan'): 0.3125,
#  ('pemberdayaan', 'perempuan', 'dan'): 0.09,
#  ('perempuan', 'dan', 'perlindungan'): 0.030303030303030304,
#  ('dan', 'perlindungan', 'anak'): 0.03864734299516908,
#  ('perlindungan', 'anak', 'atau'): 0.002421307506053269,
#  ('anak', 'atau', 'kemenpppa'): 0.0024096385542168677,
#  ('atau', 'kemenpppa', 'mencatat'): 0.014925373134328358,
#  ('kemenpppa', 'mencatat', 'hampir'): 0.058823529411764705,
#  ('mencatat', 'hampir', '2'): 0.047619047619047616,
#  ('hampir', '2', 'ribu'): 0.05555555555555555,
#  ('2', 'ribu', 'anak'): 0.08333333333333333,
#  ('ribu', 'anak', 'menjadi'): 0.002840909090909091,
#  ('anak', 'menjadi', 'korban'): 0.01201923076923077,
#  ('menjadi', 'korban', 'kekerasan'): 0.07407407407407407,
#  ('korban', 'kekerasan', 'seksual'): 0.01634877384196185,
#  ('kekerasan', 'seksual', 'selama'): 0.002932551319648094,
#  ('seksual', 'selama', 'pandemi'): 0.008,
#  ('</s>', '<s>', 'tepatnya'): 0.0007363770250368188,
#  ('<s>', 'tepatnya', ','): 0.0014705882352941176,
#  ('tepatnya', ',', '1.962'): 0.000998003992015968,
#  (',', '1.962', 'anak'): 0.000998003992015968,
#  ('1.962', 'anak', 'menjadi'): 0.002840909090909091,
#  ('kekerasan', 'seksual', '.'): 0.008797653958944282,
#  ('seksual', '.', '</s>'): 0.005571030640668524,
#  ('</s>', '<s>', 'angka'): 0.0029455081001472753,
#  ('<s>', 'angka', 'ini'): 0.0028735632183908046,
#  ('angka', 'ini', 'menunjukkan'): 0.007246376811594203,
#  ('ini', 'menunjukkan', 'kekerasan'): 0.007575757575757576,
#  ('menunjukkan', 'kekerasan', 'seksual'): 0.003246753246753247,
#  ('kekerasan', 'seksual', 'mendominasi'): 0.002932551319648094,
#  ('seksual', 'mendominasi', 'dari'): 0.021739130434782608,
#  ('mendominasi', 'dari', 'semua'): 0.0072992700729927005,
#  ('dari', 'semua', 'kasus'): 0.006535947712418301,
#  ('semua', 'kasus', 'kekerasan'): 0.006622516556291391,
#  ('kasus', 'kekerasan', 'pada'): 0.004651162790697674,
#  ('kekerasan', 'pada', 'anak'): 0.05227272727272727,
#  ('pada', 'anak', 'dengan'): 0.0020242914979757085,
#  ('anak', 'dengan', 'total'): 0.002136752136752137,
#  ('dengan', 'total', '3.297'): 0.008130081300813009,
#  ('total', '3.297', 'kasus'): 0.14285714285714285,
#  ('3.297', 'kasus', '.'): 0.007462686567164179,
#  ('kasus', '.', '</s>'): 0.012391573729863693,
#  ('</s>', '<s>', 'ilustrasi'): 0.0007363770250368188,
#  ('<s>', 'ilustrasi', 'kekerasan'): 0.0014684287812041115,
#  ('ilustrasi', 'kekerasan', 'seksual'): 0.0033444816053511705,
#  ('kekerasan', 'seksual', 'pada'): 0.005865102639296188,
#  ('seksual', 'pada', 'anak'): 0.0106951871657754,
#  ('pada', 'anak', '('): 0.0020242914979757085,
#  ('anak', '(', 'shutterstock'): 0.0021645021645021645,
#  ('(', 'shutterstock', ')'): 0.008928571428571428,
#  ('shutterstock', ')', '.'): 0.008928571428571428,
#  ('</s>', '<s>', 'asisten'): 0.0014727540500736377,
#  ('<s>', 'asisten', 'deputi'): 0.002936857562408223,
#  ('asisten', 'deputi', 'bidang'): 0.1111111111111111,
#  ('deputi', 'bidang', 'perlindungan'): 0.2,
#  ('bidang', 'perlindungan', 'anak'): 0.05714285714285714,
#  ('perlindungan', 'anak', 'dari'): 0.007263922518159807,
#  ('anak', 'dari', 'kekerasan'): 0.012345679012345678,
#  ('dari', 'kekerasan', 'dan'): 0.004629629629629629,
#  ('kekerasan', 'dan', 'eksploitasi'): 0.0030816640986132513,
#  ('dan', 'eksploitasi', ','): 0.0027397260273972603,
#  ('eksploitasi', ',', 'valentina'): 0.0009861932938856016,
#  (',', 'valentina', 'gintings'): 0.0009900990099009901,
#  ('valentina', 'gintings', ','): 0.1,
#  ('gintings', ',', 'mengatakan'): 0.000998003992015968,
#  (',', 'mengatakan', 'ini'): 0.0009624639076034649,
#  ('mengatakan', 'ini', 'hanyalah'): 0.006289308176100629,
#  ('ini', 'hanyalah', 'kasus'): 0.00819672131147541,
#  ('hanyalah', 'kasus', 'yang'): 0.007462686567164179,
#  ('kasus', 'yang', 'terlapor'): 0.001953125,
#  ('yang', 'terlapor', 'atau'): 0.002631578947368421,
#  ('terlapor', 'atau', 'mengadu'): 0.015384615384615385,
#  ('atau', 'mengadu', '.'): 0.014285714285714285,
#  ('mengadu', '.', '</s>'): 0.0014705882352941176,
#  ('</s>', '<s>', 'sedangkan'): 0.004418262150220913,
#  ('<s>', 'sedangkan', 'mereka'): 0.0014577259475218659,
#  ('sedangkan', 'mereka', 'yang'): 0.015625,
#  ('mereka', 'yang', 'tidak'): 0.0022935779816513763,
#  ('yang', 'tidak', 'berani'): 0.0020242914979757085,
#  ('tidak', 'berani', 'berbicara'): 0.008547008547008548,
#  ('berani', 'berbicara', 'atau'): 0.3333333333333333,
#  ('berbicara', 'atau', 'melapor'): 0.015384615384615385,
#  ('atau', 'melapor', 'seumpama'): 0.014925373134328358,
#  ('melapor', 'seumpama', 'gunung'): 0.25,
#  ('seumpama', 'gunung', 'es'): 0.25,
#  ('gunung', 'es', ','): 0.16666666666666666,
#  ('es', ',', 'di'): 0.00099601593625498,
#  (',', 'di', 'mana'): 0.0031446540880503146,
#  ('di', 'mana', 'jumlahnya'): 0.0036101083032490976,
#  ('mana', 'jumlahnya', 'lebih'): 0.1,
#  ('jumlahnya', 'lebih', 'banyak'): 0.02,
#  ('lebih', 'banyak', 'dari'): 0.01834862385321101,
#  ('banyak', 'dari', 'ini'): 0.005050505050505051,
#  ('dari', 'ini', '.'): 0.00390625,
#  ('<s>', '``', 'sebenernya'): 0.0012903225806451613,
#  ('``', 'sebenernya', 'data'): 0.010309278350515464,
#  ('sebenernya', 'data', 'dari'): 0.03333333333333333,
#  ('data', 'dari', 'lapangan'): 0.006097560975609756,
#  ('dari', 'lapangan', ','): 0.007246376811594203,
#  ('lapangan', ',', 'data'): 0.00099601593625498,
#  (',', 'data', 'yang'): 0.001941747572815534,
#  ('data', 'yang', 'melaporkan'): 0.0024509803921568627,
#  ('yang', 'melaporkan', 'kasus'): 0.002544529262086514,
#  ('melaporkan', 'kasus', 'itu'): 0.006802721088435374,
#  ('kasus', 'itu', 'ke'): 0.004347826086956522,
#  ('itu', 'ke', 'pelayanan'): 0.007751937984496124,
#  ('ke', 'pelayanan', 'kita'): 0.02631578947368421,
#  ('pelayanan', 'kita', ','): 0.02702702702702703,
#  ('kita', ',', 'dari'): 0.0009689922480620155,
#  (',', 'dari', 'tingkat'): 0.0008802816901408451,
#  ('dari', 'tingkat', 'kabupaten'): 0.006711409395973154,
#  ('tingkat', 'kabupaten', 'sampai'): 0.0625,
#  ('kabupaten', 'sampai', 'tingkat'): 0.06666666666666667,
#  ('sampai', 'tingkat', 'provinsi'): 0.037037037037037035,
#  ('tingkat', 'provinsi', '.'): 0.045454545454545456,
#  ('provinsi', '.', '</s>'): 0.002932551319648094,
#  ('</s>', '<s>', 'kalau'): 0.0022091310751104565,
#  ('<s>', 'kalau', 'dia'): 0.0014285714285714286,
#  ('kalau', 'dia', 'nggak'): 0.015151515151515152,
#  ('dia', 'nggak', 'melaporkan'): 0.01818181818181818,
#  ('nggak', 'melaporkan', ','): 0.041666666666666664,
#  ('melaporkan', ',', 'makanya'): 0.0009852216748768472,
#  (',', 'makanya', 'kita'): 0.0009970089730807576,
#  ('makanya', 'kita', 'selalu'): 0.030303030303030304,
#  ('kita', 'selalu', 'bilang'): 0.02702702702702703,
#  ('selalu', 'bilang', 'fenomena'): 0.1111111111111111,
#  ('bilang', 'fenomena', 'gunung'): 0.14285714285714285,
#  ('fenomena', 'gunung', 'es'): 0.2857142857142857,
#  ('gunung', 'es', 'itu'): 0.16666666666666666,
#  ('es', 'itu', "''"): 0.01,
#  ('itu', "''", 'ujar'): 0.005235602094240838,
#  ("''", 'ujar', 'valentina'): 0.009174311926605505,
#  ('ujar', 'valentina', 'saat'): 0.041666666666666664,
#  ('valentina', 'saat', 'dihubungi'): 0.016129032258064516,
#  ('saat', 'dihubungi', 'suara.com'): 0.046875,
#  ('dihubungi', 'suara.com', 'beberapa'): 0.0625,
#  ('suara.com', 'beberapa', 'waktu'): 0.043478260869565216,
#  ('beberapa', 'waktu', 'lalu'): 0.06818181818181818,
#  ('waktu', 'lalu', '.'): 0.07142857142857142,
#  ('lalu', '.', '</s>'): 0.008695652173913044,
#  ('</s>', '<s>', 'meski'): 0.0014727540500736377,
#  ('<s>', 'meski', 'tidak'): 0.00145985401459854,
#  ('meski', 'tidak', 'bisa'): 0.008264462809917356,
#  ('tidak', 'bisa', 'secara'): 0.005917159763313609,
#  ('bisa', 'secara', 'tegas'): 0.010416666666666666,
#  ('secara', 'tegas', 'menyatakan'): 0.022727272727272728,
#  ('tegas', 'menyatakan', 'kekerasan'): 0.125,
#  ('menyatakan', 'kekerasan', 'pada'): 0.0033003300330033004,
#  ('pada', 'anak', 'selalu'): 0.0020242914979757085,
#  ('anak', 'selalu', 'meningkat'): 0.0028011204481792717,
#  ('selalu', 'meningkat', ','): 0.027777777777777776,
#  ('meningkat', ',', 'tapi'): 0.0009699321047526673,
#  (',', 'tapi', 'berdasarkan'): 0.0009881422924901185,
#  ('tapi', 'berdasarkan', 'hasil'): 0.038461538461538464,
#  ('hasil', 'survei', 'prevalensi'): 0.06666666666666667,
#  ('survei', 'prevalensi', 'atau'): 0.07142857142857142,
#  ('prevalensi', 'atau', 'diperkirakan'): 0.015151515151515152,
#  ('atau', 'diperkirakan', '2'): 0.015151515151515152,
#  ('diperkirakan', '2', 'dari'): 0.07692307692307693,
#  ('2', 'dari', '3'): 0.0136986301369863,
#  ('dari', '3', 'anak'): 0.014492753623188406,
#  ('3', 'anak', 'telah'): 0.002824858757062147,
#  ('anak', 'telah', 'mengalami'): 0.002617801047120419,
#  ('telah', 'mengalami', 'kekerasan'): 0.015384615384615385,
#  ('</s>', '<s>', 'ini'): 0.005891016200294551,
#  ('<s>', 'ini', 'angka'): 0.00125,
#  ('ini', 'angka', 'yang'): 0.007246376811594203,
#  ('angka', 'yang', 'sangat'): 0.0025252525252525255,
#  ('yang', 'sangat', 'tinggi'): 0.0025188916876574307,
#  ('sangat', 'tinggi', ','): 0.03571428571428571,
#  ('tinggi', ',', 'bahkan'): 0.0009891196834817012,
#  (',', 'bahkan', 'diprediksi'): 0.0009900990099009901,
#  ('bahkan', 'diprediksi', 'lebih'): 0.08333333333333333,
#  ('diprediksi', 'lebih', '75'): 0.02040816326530612,
#  ('lebih', '75', 'persen'): 0.02127659574468085,
#  ('75', 'persen', 'anak'): 0.03125,
#  ('persen', 'anak', 'mengalaminya'): 0.002617801047120419,
#  ('anak', 'mengalaminya', '.'): 0.002840909090909091,
#  ('mengalaminya', '.', '</s>'): 0.0014814814814814814,
#  ('<s>', '``', 'kita'): 0.0012903225806451613,
#  ('``', 'kita', 'lakukan'): 0.007874015748031496,
#  ('kita', 'lakukan', 'survei'): 0.030303030303030304,
#  ('lakukan', 'survei', 'pengalaman'): 0.07142857142857142,
#  ('survei', 'pengalaman', 'hidup'): 0.058823529411764705,
#  ('pengalaman', 'hidup', 'anak'): 0.1,
#  ('hidup', 'anak', 'dan'): 0.0028089887640449437,
#  ('anak', 'dan', 'remaja'): 0.012802275960170697,
#  ('dan', 'remaja', 'itu'): 0.0027548209366391185,
#  ('remaja', 'itu', 'kan'): 0.009259259259259259,
#  ('itu', 'kan', 'sudah'): 0.00980392156862745,
#  ('kan', 'sudah', 'terlihat'): 0.02564102564102564,
#  ('sudah', 'terlihat', '2'): 0.02631578947368421,
#  ('terlihat', '2', 'dari'): 0.06666666666666667,
#  ('3', 'anak', ','): 0.002824858757062147,
#  ('anak', ',', 'usia'): 0.0007396449704142012,
#  (',', 'usia', '13'): 0.0009910802775024777,
#  ('usia', '13', 'hingga'): 0.1,
#  ('13', 'hingga', '17'): 0.043478260869565216,
#  ('hingga', '17', 'tahun'): 0.041666666666666664,
#  ('17', 'tahun', ','): 0.03125,
#  ('tahun', ',', 'respondennya'): 0.000970873786407767,
#  (',', 'respondennya', 'pernah'): 0.000998003992015968,
#  ('respondennya', 'pernah', 'mengalami'): 0.1,
#  ('pernah', 'mengalami', 'salah'): 0.023255813953488372,
#  ('mengalami', 'salah', 'satu'): 0.017857142857142856,
#  ('salah', 'satu', 'bentuk'): 0.02,
#  ('satu', 'bentuk', 'kekerasan'): 0.029411764705882353,
#  ('bentuk', 'kekerasan', ','): 0.0033003300330033004,
#  ('kekerasan', ',', "''"): 0.0023112480739599386,
#  (',', "''", 'ungkapnya'): 0.0009132420091324201,
#  ("''", 'ungkapnya', '.'): 0.010526315789473684,
#  ('ungkapnya', '.', '</s>'): 0.0014814814814814814,
#  ('</s>', '<s>', 'harusnya'): 0.0007363770250368188,
#  ('<s>', 'harusnya', 'lebih'): 0.0014705882352941176,
#  ('harusnya', 'lebih', 'banyak'): 0.02127659574468085,
#  ('lebih', 'banyak', 'di'): 0.009174311926605505,
#  ('banyak', 'di', 'rumah'): 0.005988023952095809,
#  ('di', 'rumah', 'jadi'): 0.0024937655860349127,
#  ('rumah', 'jadi', 'saat'): 0.006535947712418301,
#  ('jadi', 'saat', 'terbaik'): 0.013157894736842105,
#  ('saat', 'terbaik', 'untuk'): 0.018518518518518517,
#  ('terbaik', 'untuk', 'berkumpul'): 0.008620689655172414,
#  ('untuk', 'berkumpul', 'bersama'): 0.008620689655172414,
#  ('berkumpul', 'bersama', 'keluarga'): 0.0625,
#  ('bersama', 'keluarga', '.'): 0.01639344262295082,
#  ('keluarga', '.', '</s>'): 0.006944444444444444,
#  ('</s>', '<s>', 'tapi'): 0.0014727540500736377,
#  ('<s>', 'tapi', 'orangtua'): 0.0014492753623188406,
#  ('tapi', 'orangtua', 'tetap'): 0.02,
#  ('orangtua', 'tetap', 'bekerja'): 0.01639344262295082,
#  ('tetap', 'bekerja', 'meski'): 0.03225806451612903,
#  ('bekerja', 'meski', 'di'): 0.06666666666666667,
#  ('meski', 'di', 'rumah'): 0.0036101083032490976,
#  ('di', 'rumah', ','): 0.02493765586034913,
#  ('rumah', ',', 'dan'): 0.0008841732979664014,
#  (',', 'dan', 'kesibukan'): 0.0007390983000739098,
#  ('dan', 'kesibukan', 'itulah'): 0.0028328611898017,
#  ('kesibukan', 'itulah', 'yang'): 0.5,
#  ('itulah', 'yang', 'akhirnya'): 0.002631578947368421,
#  ('yang', 'akhirnya', 'jadi'): 0.0025906735751295338,
#  ('akhirnya', 'jadi', 'peluang'): 0.03333333333333333,
#  ('jadi', 'peluang', 'anak'): 0.04,
#  ('peluang', 'anak', 'menjadi'): 0.0028328611898017,
#  ('korban', 'kekerasan', 'saat'): 0.0027247956403269754,
#  ('kekerasan', 'saat', 'mereka'): 0.002857142857142857,
#  ('saat', 'mereka', 'belajar'): 0.00909090909090909,
#  ('mereka', 'belajar', 'di'): 0.011904761904761904,
#  ('belajar', 'di', 'rumah'): 0.030201342281879196,
#  ('di', 'rumah', '.'): 0.032418952618453865,
#  ('rumah', '.', '</s>'): 0.028606965174129355,
#  ('</s>', '<s>', 'ditambah'): 0.0007363770250368188,
#  ('<s>', 'ditambah', 'bertemu'): 0.0014619883040935672,
#  ('ditambah', 'bertemu', 'dengan'): 0.08333333333333333,
#  ('bertemu', 'dengan', 'keadaan'): 0.008064516129032258,
#  ('dengan', 'keadaan', 'dan'): 0.008,
#  ('keadaan', 'dan', 'orang'): 0.002777777777777778,
#  ('dan', 'orang', 'yang'): 0.0022522522522522522,
#  ('orang', 'yang', 'sama'): 0.0021231422505307855,
#  ('yang', 'sama', 'setiap'): 0.0025575447570332483,
#  ('sama', 'setiap', 'hari'): 0.05,
#  ('setiap', 'hari', '.'): 0.058823529411764705,
#  ('hari', '.', '</s>'): 0.0014641288433382138,
#  ('<s>', '``', 'bayangkan'): 0.0012903225806451613,
#  ('``', 'bayangkan', 'saja'): 0.010309278350515464,
#  ('bayangkan', 'saja', ','): 0.0625,
#  ('saja', ',', 'orang'): 0.000984251968503937,
#  (',', 'orang', 'tua'): 0.0027447392497712718,
#  ('tua', 'yang', 'nggak'): 0.0022522522522522522,
#  ('yang', 'nggak', 'pernah'): 0.002570694087403599,
#  ('nggak', 'pernah', 'belajar'): 0.05263157894736842,
#  ('pernah', 'belajar', 'tentang'): 0.027777777777777776,
#  ('belajar', 'tentang', 'bagaimana'): 0.022222222222222223,
#  ('tentang', 'bagaimana', 'menjadi'): 0.03333333333333333,
#  ('bagaimana', 'menjadi', 'guru'): 0.012987012987012988,
#  ('menjadi', 'guru', ','): 0.013513513513513514,
#  ('guru', ',', 'kemudian'): 0.0009900990099009901,
#  (',', 'kemudian', 'harus'): 0.0009765625,
#  ('kemudian', 'harus', 'menjadi'): 0.016129032258064516,
#  ('harus', 'menjadi', 'guru'): 0.009615384615384616,
#  ('menjadi', 'guru', '.'): 0.013513513513513514,
#  ('guru', '.', '</s>'): 0.0014641288433382138,
#  ('</s>', '<s>', 'ada'): 0.0014727540500736377,
#  ('<s>', 'ada', 'proses'): 0.0013458950201884253,
#  ('ada', 'proses', 'psikologi'): 0.014285714285714285,
#  ('proses', 'psikologi', 'yang'): 0.09090909090909091,
#  ('psikologi', 'yang', 'kemudian'): 0.0026041666666666665,
#  ('yang', 'kemudian', 'menyebabkan'): 0.0024875621890547263,
#  ('kemudian', 'menyebabkan', 'ada'): 0.029411764705882353,
#  ('menyebabkan', 'ada', 'salah'): 0.013333333333333334,
#  ('ada', 'salah', 'komunikasi'): 0.011627906976744186,
#  ('salah', 'komunikasi', 'antara'): 0.034482758620689655,
#  ('komunikasi', 'antara', 'anak'): 0.03333333333333333,
#  ('antara', 'anak', 'dan'): 0.0053475935828877,
#  ('orang', 'tua', '.'): 0.03184713375796178,
#  ('tua', '.', '</s>'): 0.006765899864682003,
#  ('</s>', '<s>', 'nah'): 0.0007363770250368188,
#  ('<s>', 'nah', ','): 0.0014705882352941176,
#  ('nah', ',', 'itu'): 0.000998003992015968,
#  (',', 'itu', 'yang'): 0.0009107468123861566,
#  ('itu', 'yang', 'sebenarnya'): 0.0021008403361344537,
#  ('yang', 'sebenarnya', 'kasus'): 0.0025906735751295338,
#  ('sebenarnya', 'kasus', 'kekerasan'): 0.007142857142857143,
#  ('kasus', 'kekerasan', 'itu'): 0.002325581395348837,
#  ('kekerasan', 'itu', 'lebih'): 0.0025380710659898475,
#  ('itu', 'lebih', 'ke'): 0.006993006993006993,
#  ('lebih', 'ke', 'arah'): 0.01282051282051282,
#  ('ke', 'arah', 'situ'): 0.029411764705882353,
#  ('arah', 'situ', ','): 0.2,
#  ('situ', ',', "''"): 0.00099601593625498,
#  (',', "''", 'paparnya'): 0.0018264840182648401,
#  ("''", 'paparnya', '.'): 0.020833333333333332,
#  ('paparnya', '.', '</s>'): 0.0029585798816568047,
#  ('</s>', '<s>', 'rumah'): 0.0014727540500736377,
#  ('<s>', 'rumah', 'tidak'): 0.0012360939431396785,
#  ...}

# %%
#fungsi ini digunakan untuk proses prediksi, yaitu mencari probabilitas trigram tertinggi 
def get_max_trigram_prob(prev_words):
    prev_words = prev_words.split()
    max_prob_next_word = ''
    trigram_cand = {k: v for k, v in trigram_prob_tab.items() if (k[0]==prev_word[0] and k[1]==prev_word[1])}
    if len(trigram_cand) > 0:
        trigram_cand = sorted(trigram_cand.items(), key=lambda x: x[1], reverse=True)
        k = trigram_cand[0]
        max_prob_next_word = k[0][2]
    return max_prob_next_word

# %%
kalimat_prediksi = "dalam survei" #masukkan inputan sesuai dengan yang diinginkan, terdiri dari 2 kata
print("kalimat prediksi trigram : " + kalimat_prediksi)
# Out:
# kalimat prediksi trigram : dalam survei

# %%
#menampilkan kata yang di prediksi sesuai dengan inputan @kalimat_prediksi
predicted_next_word = get_max_trigram_prob(kalimat_prediksi)
if len(predicted_next_word) > 0:
  print('prediksi kata selanjutnya setelah kalimat '+'\"'+kalimat_prediksi+"\""+' adalah '+"\""+predicted_next_word+"\"")
else:
  print('kata sebelum tidak ditemukan di vocabulary')
# Out:
# prediksi kata selanjutnya setelah kalimat "dalam survei" adalah "secara"

# %% [markdown]
# ## EVALUASI

# %%
top10_unigram = sorted(freq_tab.items(), key=lambda x: x[1], reverse=True)

# %%
print("Berikut merupakan kata yang paling sering muncul pada unigram")
print(top10_unigram[:15])
# Out:
# Berikut merupakan kata yang paling sering muncul pada unigram
# [(',', 1001), ('<s>', 679), ('</s>', 679), ('.', 674), ('yang', 379), ('dan', 352), ('anak', 351), ('kekerasan', 297), ('di', 271), ('perempuan', 176), ('pada', 143), ('dari', 135), ('kasus', 133), ('rumah', 130), ('pandemi', 125)]

# %%
top10_bigram = sorted(tab_prob_bigram_ls.items(), key=lambda x: x[1], reverse=True)

# %%
print("Berikut merupakan kata dengan probabilitas tertinggi pada bigram")
print(top10_bigram[:15])
# Out:
# Berikut merupakan kata dengan probabilitas tertinggi pada bigram
# [(('.', '</s>'), 0.2061633281972265), (('orang', 'tua'), 0.02478407810739767), (('<s>', '``'), 0.024307692307692308), (('di', 'rumah'), 0.02322308233638283), (('pandemi', 'covid-19'), 0.02188427299703264), ((',', "''"), 0.02127659574468085), (('kasus', 'kekerasan'), 0.021079881656804734), (('kekerasan', 'terhadap'), 0.018479776847977684), (('perempuan', 'dan'), 0.017837641062977794), ((',', 'dan'), 0.017637178051511757), (('perlindungan', 'anak'), 0.014812001519179644), (('anak', '.'), 0.014373716632443531), (('masa', 'pandemi'), 0.014100609756097561), (('pada', 'anak'), 0.01400147383935151), (('selama', 'pandemi'), 0.013951734539969835)]
